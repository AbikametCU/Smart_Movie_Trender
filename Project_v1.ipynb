# %% [markdown]
# Semester Project

# %%
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

import numpy as np
import pandas as pd
from sklearn import svm, metrics
from sklearn.svm import SVC
from sklearn import preprocessing
from sklearn import ensemble
from sklearn.utils import shuffle
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import RFE
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix,roc_curve, roc_auc_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.feature_selection import RFECV
from sklearn.model_selection import train_test_split

from collections import defaultdict
import math
from random import seed
from random import random

# %matplotlib inline

# %%
"""

https://www.guru99.com/nltk-tutorial.html
https://www.guru99.com/stemming-lemmatization-python-nltk.html
https://www.guru99.com/tokenize-words-sentences-nltk.html





#https://www.kaggle.com/stefanoleone992/imdb-extensive-dataset
a= pd.read_csv("IMDb_movies.csv")
#b= pd.read_csv("IMDb names.csv")
#c= pd.read_csv("IMDb ratings.csv")
#d= pd.read_csv("IMDb title_principals.csv")

print(a.info())


# Delete these row indexes from dataFrame
a.drop(indexNames , inplace=True)

indexNames2 = a[ a['country'] != "USA" ].index 
a.drop(indexNames2 , inplace=True)
print(a.info())
print(a.groupby("country").mean())  
print(a['country'].value_counts())
print(max(a['year']))
"""

#themoviedb
#https://www.kaggle.com/stephanerappeneau/350-000-movies-from-themoviedborg
x= pd.read_csv("AllMoviesDetailsCleaned.csv", sep=';')

print(a.info())
# Delete these row indexes from dataFrame
indexNames = a[ a['year'] <2016 ].index
a.drop(indexNames , inplace=True)

indexNames2 = a[ a['country'] != "USA" ].index 
a.drop(indexNames2 , inplace=True)
print(a.info())
print(a)

#print(b.info())
#print(c.info())
#print(d.info())
# Out:
# /home/scott/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 440 entries, 43345 to 81265
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          440 non-null    object
#  1   title                  440 non-null    object
#  2   original_title         440 non-null    object
#  3   year                   440 non-null    int64
#  4   date_published         440 non-null    object
#  5   genre                  440 non-null    object
#  6   duration               440 non-null    int64
#  7   country                440 non-null    object
#  8   language               412 non-null    object
# ...
